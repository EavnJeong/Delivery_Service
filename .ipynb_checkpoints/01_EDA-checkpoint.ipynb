# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('/app/DB/code/All_colum.csv')

# %%
ndf = df.set_index(['id'])

# %%
ndf = ndf.sort_values(by=['review_count'])

# %%
plt.rcParams['figure.figsize'] = [30,10] #그래프 사이즈 x,y

# %%
n1 = ndf[0:100]
n2 = ndf[100:200]
n3 = ndf[200:300]
n4 = ndf[300:400]   #20
n5 = ndf[400:500]   #20 ~ 40
n6 = ndf[500:600]   #40 ~ 80
n7 = ndf[600:700]   #80 ~ 150
n8 = ndf[700:800]   #152 ~ 315
n9 = ndf[800:900]   #326 ~ 767
n10 = ndf[900:1000] #767 ~ 8161

nn = ndf[300:900]

# %%
n_n1 = n7.loc[:,('min_order_amount','delivery_fee','review_count','price1','price2','price3')]

# %%
sns.lineplot(x = 'price1', y = 'review_count', data = nn)

# %%
sns.boxenplot(x = 'price1', y = 'review_count', color = 'b', data = nn)

# %%
sns.pairplot(n_n1)

# %%
sns.barplot()
