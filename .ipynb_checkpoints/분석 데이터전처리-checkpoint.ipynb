# %%
import pandas as pd
import numpy as np

# %%
food_data['review_count'].describe()
# Out:
# count    9233.000000
# mean      435.976822
# std       195.927386
# min       201.000000
# 25%       271.000000
# 50%       380.000000
# 75%       563.000000
# max       938.000000
# Name: review_count, dtype: float64

# %%
food_data = pd.read_csv('Eavn.csv')

# %%
food_data = food_data.iloc[:, 1:]
food_data
# Out:
#       df_index  delivery_fee  min_order_amount   price1  ...  편의점  프랜차이즈  피자양식  한식
# 0            0          2000              9000  15000.0  ...    0      0     0   0
# 1            7             0             10000   8000.0  ...    0      0     0   0
# 2           20          2000             15000  15000.0  ...    0      1     0   0
# 3           27          3000              9000   6500.0  ...    0      0     0   0
# 4           28          3000              9000   2000.0  ...    0      0     0   0
# ...        ...           ...               ...      ...  ...  ...    ...   ...  ..
# 9228    126369          2000             15000  19000.0  ...    0      1     0   0
# 9229    126759             0             14000   3000.0  ...    0      0     1   0
# 9230    126848          3500              9000   9000.0  ...    0      0     0   0
# 9231    126930          1000             14000  15000.0  ...    0      0     0   0
# 9232    127446          1000             14000  15000.0  ...    0      0     0   0
#
# [9233 rows x 26 columns]

# %%
df = food_data[['delivery_fee', 'min_order_amount', 'review_count', 'loyal_score', 'free_delivery_threshold', 'gap','1인분주문',	'분식','야식','예약픽업','일식돈까스','족발보쌈','중식','치킨','카페디저트','테이크아웃','편의점','프랜차이즈','피자양식',	'한식']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.drop('review_count', 1), df['review_count'], random_state=30)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error

my_predictions = {}
my_pred = None
my_actual = None
my_name = None

colors = ['r', 'c', 'm', 'y', 'k', 'khaki', 'teal', 'orchid', 'sandybrown',
          'greenyellow', 'dodgerblue', 'deepskyblue', 'rosybrown', 'firebrick',
          'deeppink', 'crimson', 'salmon', 'darkred', 'olivedrab', 'olive', 
          'forestgreen', 'royalblue', 'indigo', 'navy', 'mediumpurple', 'chocolate',
          'gold', 'darkorange', 'seagreen', 'turquoise', 'steelblue', 'slategray', 
          'peru', 'midnightblue', 'slateblue', 'dimgray', 'cadetblue', 'tomato'
         ]

def plot_predictions(name_, pred, actual):
    df = pd.DataFrame({'prediction': pred, 'actual': y_test})
    df = df.sort_values(by='actual').reset_index(drop=True)

    plt.figure(figsize=(11, 8))
    plt.scatter(df.index, df['prediction'], marker='x', color='r')
    plt.scatter(df.index, df['actual'], alpha=0.7, marker='o', color='black')
    plt.title(name_, fontsize=15)
    plt.legend(['prediction', 'actual'], fontsize=12)
    plt.show()

def mse_eval(name_, pred, actual):
    global my_predictions, colors, my_pred, my_actual, my_name
    
    my_name = name_
    my_pred = pred
    my_actual = actual

    plot_predictions(name_, pred, actual)

    mse = mean_squared_error(pred, actual)
    my_predictions[name_] = mse

    y_value = sorted(my_predictions.items(), key=lambda x: x[1], reverse=True)
    
    df = pd.DataFrame(y_value, columns=['model', 'mse'])
    print(df)
    min_ = df['mse'].min() - 10
    max_ = df['mse'].max() + 10
    
    length = len(df) / 2
    
    plt.figure(figsize=(9, length))
    ax = plt.subplot()
    ax.set_yticks(np.arange(len(df)))
    ax.set_yticklabels(df['model'], fontsize=12)
    bars = ax.barh(np.arange(len(df)), df['mse'], height=0.3)
    
    for i, v in enumerate(df['mse']):
        idx = np.random.choice(len(colors))
        bars[i].set_color(colors[idx])
        ax.text(v + 2, i, str(round(v, 3)), color='k', fontsize=12, fontweight='bold', verticalalignment='center')
        
    plt.title('MSE Error', fontsize=16)
    plt.xlim(min_, max_)
    
    plt.show()
    
def add_model(name_, pred, actual):
    global my_predictions, my_pred, my_actual, my_name
    my_name = name_
    my_pred = pred
    my_actual = actual
    
    mse = mean_squared_error(pred, actual)
    my_predictions[name_] = mse

def remove_model(name_):
    global my_predictions
    try:
        del my_predictions[name_]
    except KeyError:
        return False
    return True

def plot_all():
    global my_predictions, my_pred, my_actual, my_name
    
    plot_predictions(my_name, my_pred, my_actual)
    
    y_value = sorted(my_predictions.items(), key=lambda x: x[1], reverse=True)
    
    df = pd.DataFrame(y_value, columns=['model', 'mse'])
    print(df)
    min_ = df['mse'].min() - 10
    max_ = df['mse'].max() + 10
    
    length = len(df) / 2
    
    plt.figure(figsize=(9, length))
    ax = plt.subplot()
    ax.set_yticks(np.arange(len(df)))
    ax.set_yticklabels(df['model'], fontsize=12)
    bars = ax.barh(np.arange(len(df)), df['mse'], height=0.3)
    
    for i, v in enumerate(df['mse']):
        idx = np.random.choice(len(colors))
        bars[i].set_color(colors[idx])
        ax.text(v + 2, i, str(round(v, 3)), color='k', fontsize=12, fontweight='bold', verticalalignment='center')
        
    plt.title('MSE Error', fontsize=16)
    plt.xlim(min_, max_)
    
    plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures

# %%
linear_reg = LinearRegression()
linear_reg.fit(x_train, y_train)
pred = linear_reg.predict(x_test)
mse_eval('LinearRegression', pred, y_test)
# Out:
#               model           mse
# 0  LinearRegression  33008.853984

# %%
ridge = Ridge(alpha=0.1)
ridge.fit(x_train, y_train)
pred = ridge.predict(x_test)
mse_eval('Ridge(alpha=0.1)', pred, y_test)
# Out:
#               model           mse
# 0  LinearRegression  33008.853984
# 1  Ridge(alpha=0.1)  33004.391237

# %%
lasso = Lasso(alpha=0.01)
lasso.fit(x_train, y_train)
pred = lasso.predict(x_test)
mse_eval('Lasso(alpha=0.01)', pred, y_test)
# Out:
#                model           mse
# 0   LinearRegression  33008.853984
# 1   Ridge(alpha=0.1)  33004.391237
# 2  Lasso(alpha=0.01)  32990.509911

# %%
elasticnet = ElasticNet(alpha=0.01, l1_ratio=0.8)
elasticnet.fit(x_train, y_train)
pred = elasticnet.predict(x_test)
mse_eval('ElasticNet(alpha=0.1, l1_ratio=0.8)', pred, y_test)
# Out:
#                                  model           mse
# 0                     LinearRegression  33008.853984
# 1                     Ridge(alpha=0.1)  33004.391237
# 2                    Lasso(alpha=0.01)  32990.509911
# 3  ElasticNet(alpha=0.1, l1_ratio=0.8)  32921.575896

# %%
elasticnet_pipeline = make_pipeline(
    StandardScaler(),
    ElasticNet(alpha=0.01, l1_ratio=0.8)
)
elasticnet_pipeline.fit(x_train, y_train)
elasticnet_pred = elasticnet_pipeline.predict(x_test)
mse_eval('Standard ElasticNet', elasticnet_pred, y_test)
# Out:
#                                  model           mse
# 0                     LinearRegression  33008.853984
# 1                  Standard ElasticNet  33006.424491
# 2                     Ridge(alpha=0.1)  33004.391237
# 3                    Lasso(alpha=0.01)  32990.509911
# 4  ElasticNet(alpha=0.1, l1_ratio=0.8)  32921.575896

# %%
poly_pipeline = make_pipeline(
    PolynomialFeatures(degree=2, include_bias=False),
    ElasticNet(alpha=0.1, l1_ratio=0.2)
)
poly_pipeline.fit(x_train, y_train)
poly_pred = poly_pipeline.predict(x_test)
mse_eval('Poly ElasticNet', poly_pred, y_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110251994.89857474, tolerance: 26618.212668053144
#   positive)
#                                  model           mse
# 0                      Poly ElasticNet  33069.530293
# 1                     LinearRegression  33008.853984
# 2                  Standard ElasticNet  33006.424491
# 3                     Ridge(alpha=0.1)  33004.391237
# 4                    Lasso(alpha=0.01)  32990.509911
# 5  ElasticNet(alpha=0.1, l1_ratio=0.8)  32921.575896

# %%
single_models = [
    ('linear_reg', linear_reg), 
    ('ridge', ridge), 
    ('lasso', lasso), 
    ('elasticnet_pipeline', elasticnet_pipeline), 
    ('poly_pipeline', poly_pipeline)
]

# %%
from sklearn.ensemble import VotingRegressor, VotingClassifier
voting_regressor = VotingRegressor(single_models, n_jobs=-1)
voting_regressor.fit(x_train, y_train)
voting_pred = voting_regressor.predict(x_test)
mse_eval('Voting Ensemble', voting_pred, y_test)
# Out:
#                                  model           mse
# 0                      Poly ElasticNet  33069.530293
# 1                     LinearRegression  33008.853984
# 2                  Standard ElasticNet  33006.424491
# 3                     Ridge(alpha=0.1)  33004.391237
# 4                    Lasso(alpha=0.01)  32990.509911
# 5  ElasticNet(alpha=0.1, l1_ratio=0.8)  32921.575896
# 6                      Voting Ensemble  32918.599210

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier

models = [
    ('Logi', LogisticRegression()), 
    ('ridge', RidgeClassifier())
]
vc = VotingClassifier(models, voting='hard')
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
rfr = RandomForestRegressor()
rfr.fit(x_train, y_train)
rfr_pred = rfr.predict(x_test)
mse_eval('RandomForest Ensemble', rfr_pred, y_test)
# Out:
#                                  model           mse
# 0                      Poly ElasticNet  33069.530293
# 1                     LinearRegression  33008.853984
# 2                  Standard ElasticNet  33006.424491
# 3                     Ridge(alpha=0.1)  33004.391237
# 4                    Lasso(alpha=0.01)  32990.509911
# 5  ElasticNet(alpha=0.1, l1_ratio=0.8)  32921.575896
# 6                      Voting Ensemble  32918.599210
# 7                RandomForest Ensemble  28030.697704

# %%
rfr = RandomForestRegressor(random_state=42, n_estimators=1500, max_depth=5, max_features=0.9)
rfr.fit(x_train, y_train)
rfr_pred = rfr.predict(x_test)
mse_eval('RandomForest Ensemble w/ Tuning', rfr_pred, y_test)
# Out:
#                                  model           mse
# 0                      Poly ElasticNet  33069.530293
# 1                     LinearRegression  33008.853984
# 2                  Standard ElasticNet  33006.424491
# 3                     Ridge(alpha=0.1)  33004.391237
# 4                    Lasso(alpha=0.01)  32990.509911
# 5  ElasticNet(alpha=0.1, l1_ratio=0.8)  32921.575896
# 6                      Voting Ensemble  32918.599210
# 7      RandomForest Ensemble w/ Tuning  32529.752614
# 8                RandomForest Ensemble  28030.697704

# %%
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier

gbr = GradientBoostingRegressor(random_state=42)
gbr.fit(x_train, y_train)
gbr_pred = gbr.predict(x_test)
mse_eval('GradientBoost Ensemble', gbr_pred, y_test)
# Out:
#                                  model           mse
# 0                      Poly ElasticNet  33069.530293
# 1                     LinearRegression  33008.853984
# 2                  Standard ElasticNet  33006.424491
# 3                     Ridge(alpha=0.1)  33004.391237
# 4                    Lasso(alpha=0.01)  32990.509911
# 5  ElasticNet(alpha=0.1, l1_ratio=0.8)  32921.575896
# 6                      Voting Ensemble  32918.599210
# 7      RandomForest Ensemble w/ Tuning  32529.752614
# 8               GradientBoost Ensemble  32246.612507
# 9                RandomForest Ensemble  28030.697704

# %%
gbr = GradientBoostingRegressor(random_state=35, learning_rate=0.01)
gbr.fit(x_train, y_train)
gbr_pred = gbr.predict(x_test)
mse_eval('GradientBoosting(lr=0.01)', gbr_pred, y_test)
# Out:
#                                   model           mse
# 0             GradientBoosting(lr=0.01)  33563.271853
# 1                       Poly ElasticNet  33069.530293
# 2                      LinearRegression  33008.853984
# 3                   Standard ElasticNet  33006.424491
# 4                      Ridge(alpha=0.1)  33004.391237
# 5                     Lasso(alpha=0.01)  32990.509911
# 6   ElasticNet(alpha=0.1, l1_ratio=0.8)  32921.575896
# 7                       Voting Ensemble  32918.599210
# 8       RandomForest Ensemble w/ Tuning  32529.752614
# 9                GradientBoost Ensemble  32246.612507
# 10                RandomForest Ensemble  28030.697704

# %%
gbr = GradientBoostingRegressor(random_state=49, learning_rate=0.01, n_estimators=1000)
gbr.fit(x_train, y_train)
gbr_pred = gbr.predict(x_test)
mse_eval('GradientBoosting(lr=0.01, est=1000)', gbr_pred, y_test)
# Out:
#                                   model           mse
# 0             GradientBoosting(lr=0.01)  33563.271853
# 1                       Poly ElasticNet  33069.530293
# 2                      LinearRegression  33008.853984
# 3                   Standard ElasticNet  33006.424491
# 4                      Ridge(alpha=0.1)  33004.391237
# 5                     Lasso(alpha=0.01)  32990.509911
# 6   ElasticNet(alpha=0.1, l1_ratio=0.8)  32921.575896
# 7                       Voting Ensemble  32918.599210
# 8       RandomForest Ensemble w/ Tuning  32529.752614
# 9                GradientBoost Ensemble  32246.612507
# 10  GradientBoosting(lr=0.01, est=1000)  32243.038692
# 11                RandomForest Ensemble  28030.697704

# %%
gbr = GradientBoostingRegressor(random_state=SEED, learning_rate=0.01, n_estimators=1000, subsample=0.8)
gbr.fit(x_train, y_train)
gbr_pred = gbr.predict(x_test)
mse_eval('GradientBoosting(lr=0.01, est=1000, subsample=0.8)', gbr_pred, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-56e247de4d66> in <module>()
# ----> 1 gbr = GradientBoostingRegressor(random_state=SEED, learning_rate=0.01, n_estimators=1000, subsample=0.8)
#       2 gbr.fit(x_train, y_train)
#       3 gbr_pred = gbr.predict(x_test)
#       4 mse_eval('GradientBoosting(lr=0.01, est=1000, subsample=0.8)', gbr_pred, y_test)
#
# NameError: name 'SEED' is not defined

# %%
from xgboost import XGBRegressor, XGBClassifier
xgb = XGBRegressor(random_state=28)
xgb.fit(x_train, y_train)
xgb_pred = xgb.predict(x_test)
mse_eval('XGBoost', xgb_pred, y_test)
# Out:
# [15:26:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#                                   model           mse
# 0             GradientBoosting(lr=0.01)  33563.271853
# 1                       Poly ElasticNet  33069.530293
# 2                      LinearRegression  33008.853984
# 3                   Standard ElasticNet  33006.424491
# 4                      Ridge(alpha=0.1)  33004.391237
# 5                     Lasso(alpha=0.01)  32990.509911
# 6   ElasticNet(alpha=0.1, l1_ratio=0.8)  32921.575896
# 7                       Voting Ensemble  32918.599210
# 8       RandomForest Ensemble w/ Tuning  32529.752614
# 9                               XGBoost  32269.154528
# 10               GradientBoost Ensemble  32246.612507
# 11  GradientBoosting(lr=0.01, est=1000)  32243.038692
# 12                RandomForest Ensemble  28030.697704

# %%
xgb = XGBRegressor(random_state=42, learning_rate=0.01, n_estimators=1000, subsample=0.8, max_features=0.8, max_depth=7)
xgb.fit(x_train, y_train)
xgb_pred = xgb.predict(x_test)
mse_eval('XGBoost w/ Tuning', xgb_pred, y_test)
# Out:
# [15:26:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#                                   model           mse
# 0             GradientBoosting(lr=0.01)  33563.271853
# 1                       Poly ElasticNet  33069.530293
# 2                      LinearRegression  33008.853984
# 3                   Standard ElasticNet  33006.424491
# 4                      Ridge(alpha=0.1)  33004.391237
# 5                     Lasso(alpha=0.01)  32990.509911
# 6   ElasticNet(alpha=0.1, l1_ratio=0.8)  32921.575896
# 7                       Voting Ensemble  32918.599210
# 8       RandomForest Ensemble w/ Tuning  32529.752614
# 9                               XGBoost  32269.154528
# 10               GradientBoost Ensemble  32246.612507
# 11  GradientBoosting(lr=0.01, est=1000)  32243.038692
# 12                    XGBoost w/ Tuning  29836.072344
# 13                RandomForest Ensemble  28030.697704

# %%
from lightgbm import LGBMRegressor, LGBMClassifier

lgbm = LGBMRegressor(random_state=5)
lgbm.fit(x_train, y_train)
lgbm_pred = lgbm.predict(x_test)
mse_eval('LGBM', lgbm_pred, y_test)
# Out:
#                                   model           mse
# 0             GradientBoosting(lr=0.01)  33563.271853
# 1                       Poly ElasticNet  33069.530293
# 2                      LinearRegression  33008.853984
# 3                   Standard ElasticNet  33006.424491
# 4                      Ridge(alpha=0.1)  33004.391237
# 5                     Lasso(alpha=0.01)  32990.509911
# 6   ElasticNet(alpha=0.1, l1_ratio=0.8)  32921.575896
# 7                       Voting Ensemble  32918.599210
# 8       RandomForest Ensemble w/ Tuning  32529.752614
# 9                               XGBoost  32269.154528
# 10               GradientBoost Ensemble  32246.612507
# 11  GradientBoosting(lr=0.01, est=1000)  32243.038692
# 12                                 LGBM  31446.414415
# 13                    XGBoost w/ Tuning  29836.072344
# 14                RandomForest Ensemble  28030.697704
