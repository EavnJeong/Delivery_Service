# %% [markdown]
# ## 1. 업종별 속성 분석
# ## 2. 데이터 프레임

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import operator

# %%
df_7 = pd.DataFrame()
# 천만개 읽기
for cnt, chunk in enumerate(pd.read_csv(pile_path, chunksize=10000000)):
    chunk = chunk[chunk['기준년월']==201907]
    df_7 = pd.concat([df_7,chunk])    
    
    if cnt == 5:
        break

# %% [markdown]
# # 1.3억 6000만개 추출

# %%
print('7월 데이터 4866519 개의 데이터 under 8000')
# Out:
# 7월 데이터 4866519 개의 데이터 under 8000

# %%
sort_index = ['슈퍼 마켓', '편 의 점',
       '인터넷Mall', '인터넷 P/G', '약국',
       '기타음료식품', 
      '문구용 품',  '대형할인점', 
       '인터넷종합Mall','화 장 품',
       '복지 매점', '기타건강식']

# %%
sort_index_food = ['일반한식','일식회집', '중국음식','한정식','갈비전문점', '서양음식']

# %%
no_food_data = df_7[df_7['업종별'].isin(sort_index)]

# %%
food_data = df_7[df_7['업종별'].isin(sort_index_food)]

# %%
A = np.array(no_food_data['매출금액']) [0:500]
B = np.array(food_data['매출금액']) [0:500]
C = A + B

# %%
print('2420944 개의 데이터 음식아닌거')
# Out:
# 2420944 개의 데이터 음식아닌거

# %%
print('860084 개의 데이터 음식')
# Out:
# 860084 개의 데이터 음식

# %%
sum_data = food_data2

# %%
sum_data['매출금액2'] = 0
# Out:
# /opt/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.style.use('seaborn')
plt.figure(figsize=(30, 15))
plt.plot(list(sum_data['매출금액'])[0:1000])
plt.plot(list(sum_data['매출금액2'])[0:1000], color='orange')
plt.plot(list(sum_data['합계금액'])[0:1000])
plt.axhline(8000, color='red')
plt.ylim(0, 20000)
plt.show()

# %%
plt.figure(figsize=(30, 15))
plt.plot(list(sum_data['매출금액'])[0:1000])
plt.axhline(8000, color='red')
plt.ylim(0, 20000)
plt.show()

# %%
plt.figure(figsize=(30, 15))
plt.plot(list(sum_data['매출금액2'])[0:1000], color='orange')
plt.axhline(8000, color='red')
plt.ylim(0, 20000)
plt.show()

# %%
plt.figure(figsize=(30, 15))
plt.plot(list(sum_data['합계금액'])[0:1000], color='green')
plt.axhline(8000, color='red')
plt.ylim(0, 20000)
plt.show()

# %%
a = sum_data[0:1000]
a.describe()
# Out:
#              고객랜덤번호         매출금액          합계금액        매출금액2
# count   1000.000000  1000.000000   1000.000000  1000.000000
# mean    5253.653000  4718.070000   7351.378000  3206.918000
# std     2972.851584  1850.904866   3713.651912  2296.250142
# min       29.000000   200.000000      0.000000     0.000000
# 25%     2634.000000  3500.000000   8000.000000  1350.000000
# 50%     5612.000000  4925.000000   8400.000000  3100.000000
# 75%     7838.250000  6000.000000   9300.000000  5000.000000
# max    10447.000000  7920.000000  14580.000000  7990.000000

# %%
b = sum_data[sum_data['합계금액'] != 0]
b.describe()
# Out:
#              고객랜덤번호         매출금액          합계금액        매출금액2
# count    810.000000   810.000000    810.000000   810.000000
# mean    4987.093827  5109.333333   9075.775309  3959.158025
# std     2962.152136  1668.585939   1166.446260  1878.615550
# min       29.000000   400.000000   8000.000000     0.000000
# 25%     2623.500000  3800.000000   8200.000000  2500.000000
# 50%     4486.000000  5500.000000   8650.000000  3985.000000
# 75%     7259.000000  6500.000000   9572.500000  5495.000000
# max    10447.000000  7920.000000  14580.000000  7990.000000
